# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Q1-Read the data https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv')

# %% [markdown]
# The description of dataset is given below.
#
# •	ID: Uniquely identifies each observation (diamond)
#
# •	Carat Weight: The weight of the diamond in metric carats. One carat is equal to 0.2 grams, roughly the same weight as a paperclip
#
# •	Cut: One of five values indicating the cut of the diamond in the following order of desirability (Signature-Ideal, Ideal, Very Good, Good, Fair)
#
# •	Color: One of six values indicating the diamond's color in the following order of desirability (D, E, F - Colorless, G, H, I - Near colorless)
#
# •	Clarity: One of seven values indicating the diamond's clarity in the following order of desirability (F - Flawless, IF - Internally Flawless, VVS1 or VVS2 - Very, Very Slightly Included, or VS1 or VS2 - Very Slightly Included, SI1 - Slightly Included)
#
# •	Polish: One of four values indicating the diamond's polish (ID - Ideal, EX - Excellent, VG - Very Good, G - Good)
#
# •	Symmetry: One of four values indicating the diamond's symmetry (ID - Ideal, EX - Excellent, VG - Very Good, G - Good)
#
# •	Report: One of of two values "AGSL" or "GIA" indicating which grading agency reported the qualities of the diamond qualities
#
# •	Price: The The amount in USD that the diamond is valued

# %%
#Q2-Get first 2 rows of data

import pandas as pd

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

df.head(2)
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470

# %%
#Q3-Check if there is missing value

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)


print("missing values in each column:")
print(df.isnull().sum())


print("\nIs there any missing value in the dataset?")
print(df.isnull().values.any())
# Out:
# missing values in each column:
# Carat Weight    0
# Cut             0
# Color           0
# Clarity         0
# Polish          0
# Symmetry        0
# Report          0
# Price           0
# dtype: int64
#
# Is there any missing value in the dataset?
# False

# %%
#Q4- Get data information and number of rows and columns

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

print("Dataset information:")
df.info()

rows, cols = df.shape
print("\nNumber of rows:", rows)
print("Number of columns:", cols)
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Carat Weight  6000 non-null   float64
#  1   Cut           6000 non-null   object
#  2   Color         6000 non-null   object
#  3   Clarity       6000 non-null   object
#  4   Polish        6000 non-null   object
#  5   Symmetry      6000 non-null   object
#  6   Report        6000 non-null   object
#  7   Price         6000 non-null   int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 375.1+ KB
#
# Number of rows: 6000
# Number of columns: 8

# %%
#Q5-Get descriptive statistics of data

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

print("Descriptive Statistics (numerical Columns):")
print(df.describe())


print("\nDescriptive Statistics (all Columns):")
print(df.describe(include='all'))
# Out:
# Descriptive Statistics (numerical Columns):
#        Carat Weight          Price
# count   6000.000000    6000.000000
# mean       1.334520   11791.579333
# std        0.475696   10184.350051
# min        0.750000    2184.000000
# 25%        1.000000    5150.500000
# 50%        1.130000    7857.000000
# 75%        1.590000   15036.500000
# max        2.910000  101561.000000
#
# Descriptive Statistics (all Columns):
#         Carat Weight    Cut Color Clarity Polish Symmetry Report  \
# count    6000.000000   6000  6000    6000   6000     6000   6000
# unique           NaN      5     6       7      4        4      2
# top              NaN  Ideal     G     SI1     EX       VG    GIA
# freq             NaN   2482  1501    2059   2425     2417   5266
# mean        1.334520    NaN   NaN     NaN    NaN      NaN    NaN
# std         0.475696    NaN   NaN     NaN    NaN      NaN    NaN
# min         0.750000    NaN   NaN     NaN    NaN      NaN    NaN
# 25%         1.000000    NaN   NaN     NaN    NaN      NaN    NaN
# 50%         1.130000    NaN   NaN     NaN    NaN      NaN    NaN
# 75%         1.590000    NaN   NaN     NaN    NaN      NaN    NaN
# max         2.910000    NaN   NaN     NaN    NaN      NaN    NaN
#
#                 Price
# count     6000.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean     11791.579333
# std      10184.350051
# min       2184.000000
# 25%       5150.500000
# 50%       7857.000000
# 75%      15036.500000
# max     101561.000000

# %%
#Q6-Use seasoborns heat map to generate following heatmap
# annot = True to print the correlation inside the square

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

numeric_df = df.select_dtypes(include=np.number)

corr_matrix = numeric_df.corr()

plt.figure(figsize=(6,5))
sns.heatmap(corr_matrix,
            annot=True,
            cmap='rocket',
            fmt=".2f")

plt.title("correlation heatmap")
plt.show()

# %%
#Q7-Use seasoborns paiplot to generate following  diagram

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

numeric_df = df[["Carat Weight", "Price"]]

sns.pairplot(numeric_df)

plt.show()

# %%
#Q8-Divide the data so that get Price as ouput variable (Y) and other variables as input varable (X)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)


X = df.drop("Price", axis=1)
Y = df["Price"]

print("Shape of X:", X.shape)
print("Shape of Y:", Y.shape)

print("\nFirst 5 rows of X:")
display(X.head())

print("\nFirst 5 rows of Y:")
display(Y.head())
# Out:
# Shape of X: (6000, 7)
# Shape of Y: (6000,)
#
# First 5 rows of X:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report
# 0          1.10  Ideal     H     SI1     VG       EX    GIA
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL
# 2          0.85  Ideal     H     SI1     EX       EX    GIA
# 3          0.91  Ideal     E     SI1     VG       VG    GIA
# 4          0.83  Ideal     G     SI1     EX       EX    GIA
# First 5 rows of Y:
# 0    5169
# 1    3470
# 2    3183
# 3    4370
# 4    3171
# Name: Price, dtype: int64

# %%
#Q9-Create dummy for the input variables (X)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

X = df.drop("Price", axis=1)
Y = df["Price"]

X_dummies = pd.get_dummies(X, drop_first=True)

print("Original X shape:", X.shape)
print("X after dummy encoding shape:", X_dummies.shape)

X_dummies.head()
# Out:
# Original X shape: (6000, 7)
# X after dummy encoding shape: (6000, 23)
#    Carat Weight  Cut_Good  Cut_Ideal  Cut_Signature-Ideal  Cut_Very Good  \
# 0          1.10     False       True                False          False
# 1          0.83     False       True                False          False
# 2          0.85     False       True                False          False
# 3          0.91     False       True                False          False
# 4          0.83     False       True                False          False
#
#    Color_E  Color_F  Color_G  Color_H  Color_I  ...  Clarity_VS2  \
# 0    False    False    False     True    False  ...        False
# 1    False    False    False     True    False  ...        False
# 2    False    False    False     True    False  ...        False
# 3     True    False    False    False    False  ...        False
# 4    False    False     True    False    False  ...        False
#
#    Clarity_VVS1  Clarity_VVS2  Polish_G  Polish_ID  Polish_VG  Symmetry_G  \
# 0         False         False     False      False       True       False
# 1         False         False     False       True      False       False
# 2         False         False     False      False      False       False
# 3         False         False     False      False       True       False
# 4         False         False     False      False      False       False
#
#    Symmetry_ID  Symmetry_VG  Report_GIA
# 0        False        False        True
# 1         True        False       False
# 2        False        False        True
# 3        False         True        True
# 4        False        False        True
#
# [5 rows x 23 columns]

# %%
#Q10 -Split the input and output data into two parts: test data (20%) and train data(%80)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

X = df.drop("Price", axis=1)
Y = df["Price"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.20, random_state=42
)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (4800, 23)
# (4800,)
# (1200, 23)
# (1200,)

# %%
def evalmetric(y,ypred):
 import numpy as np
 e = y - ypred
 mse_f = np.mean(e**2)
 rmse_f = np.sqrt(mse_f)
 mae_f = np.mean(abs(e))
 mape_f = 100*np.mean(abs(e/y))
 r2_f = 1-(sum(e**2)/sum((y-np.mean(y))**2))
 print("MSE:", mse_f)
 print("RMSE:", rmse_f)
 print("MAE:",mae_f)
 print("MAPE:",mape_f)
 print("R-Squared:", r2_f)

# %%
#Q11 Use Linear regression to evaluate the performance of test and train data of Linear model  using evalmetric
from sklearn.linear_model import LinearRegression

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

X = df.drop("Price", axis=1)
Y = df["Price"]

X = pd.get_dummies(X, drop_first=True)

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.20, random_state=42
)

model = LinearRegression()
model.fit(X_train, Y_train)

Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)

print("Train Performance")
evalmetric(Y_train, Y_train_pred)

print("\nTest Performance")
evalmetric(Y_test, Y_test_pred)
# Out:
# Train Performance
# MSE: 13617878.611029424
# RMSE: 3690.240996334714
# MAE: 2420.3923973752335
# MAPE: 28.436213974145286
# R-Squared: 0.8677546171602643
#
# Test Performance
# MSE: 16395263.35943688
# RMSE: 4049.1064890216066
# MAE: 2386.8817587054814
# MAPE: 27.98432467278652
# R-Squared: 0.8461544250476118

# %% [markdown]
# Q12 -Based on the performance of test and training model, can we say there is overfitting or not in the performace of liner model?

# %% [markdown]
# There is no significant overfitting.

# %%
#Q13- Use Lasso regression to evaluate the performance of test and train data   using evalmetric
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
import pandas as pd

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

X = df.drop("Price", axis=1)
Y = df["Price"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.20, random_state=42
)

lasso = Lasso(alpha=1.0, max_iter=10000)
lasso.fit(X_train, Y_train)

Y_train_pred = lasso.predict(X_train)
Y_test_pred = lasso.predict(X_test)

print("Train Performance")
evalmetric(Y_train, Y_train_pred)

print("\nTest Performance")
evalmetric(Y_test, Y_test_pred)
# Out:
# Train Performance
# MSE: 13662562.718324026
# RMSE: 3696.2903996201417
# MAE: 2423.7828292562003
# MAPE: 28.47474843700304
# R-Squared: 0.8673206826947859
#
# Test Performance
# MSE: 16382788.84461024
# RMSE: 4047.5657924992697
# MAE: 2390.0786826760586
# MAPE: 28.02553629259828
# R-Squared: 0.846271480130149

# %%
#Q14 Use Ridge regreesionto evaluate the performance of test and train data   using evalmetric

from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
import pandas as pd

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

X = df.drop("Price", axis=1)
Y = df["Price"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.20, random_state=42
)

ridge = Ridge(alpha=1.0)
ridge.fit(X_train, Y_train)

Y_train_pred = ridge.predict(X_train)
Y_test_pred = ridge.predict(X_test)

print("Train Performance")
evalmetric(Y_train, Y_train_pred)

print("\nTest Performance")
evalmetric(Y_test, Y_test_pred)
# Out:
# Train Performance
# MSE: 13945142.760987546
# RMSE: 3734.3195847419843
# MAE: 2436.0590762300158
# MAPE: 28.66555995681942
# R-Squared: 0.8645765030033441
#
# Test Performance
# MSE: 16354795.887182316
# RMSE: 4044.1063150197124
# MAE: 2400.4165468663386
# MAPE: 28.230792730281756
# R-Squared: 0.8465341531068316

# %% [markdown]
# Q15- Did you get any improvement on test data using Ridge and Lasso?
# Explain why?

# %% [markdown]
# Ridge and Lasso did not provide meaningful improvement on test performance because the linear model was already well-generalized and not overfitting.

# %%
#Q16-Use Decison Tree Regression to evaluate the performance of test and train data   using evalmetric
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import pandas as pd

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

X = df.drop("Price", axis=1)
Y = df["Price"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.20, random_state=42
)

dt = DecisionTreeRegressor(random_state=42)
dt.fit(X_train, Y_train)

Y_train_pred = dt.predict(X_train)
Y_test_pred = dt.predict(X_test)

print("Train Performance")
evalmetric(Y_train, Y_train_pred)

print("\nTest Performance")
evalmetric(Y_test, Y_test_pred)
# Out:
# Train Performance
# MSE: 83753.97633482143
# RMSE: 289.40279254841585
# MAE: 77.53468948412699
# MAPE: 0.7629440866398477
# R-Squared: 0.999186651828738
#
# Test Performance
# MSE: 3377642.2571009025
# RMSE: 1837.836297688372
# MAE: 888.5465218253969
# MAPE: 7.167853834215014
# R-Squared: 0.9683057659010963

# %%
#Q17-Use Random Forest to evaluate the performance of test and train data   using evalmetric
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import pandas as pd

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/diamond.csv"
df = pd.read_csv(url)

X = df.drop("Price", axis=1)
Y = df["Price"]

X = pd.get_dummies(X, drop_first=True)

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.20, random_state=42
)

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, Y_train)

Y_train_pred = rf.predict(X_train)
Y_test_pred = rf.predict(X_test)

print("Train Performance")
evalmetric(Y_train, Y_train_pred)

print("\nTest Performance")
evalmetric(Y_test, Y_test_pred)
# Out:
# Train Performance
# MSE: 459930.07480541855
# RMSE: 678.181446815982
# MAE: 315.2863189831003
# MAPE: 2.5137504528128867
# R-Squared: 0.995533545968541
#
# Test Performance
# MSE: 1662704.1117658145
# RMSE: 1289.4588445413117
# MAE: 664.0046578063602
# MAPE: 5.445649651388347
# R-Squared: 0.9843979529671247

# %% [markdown]
# Q18-Why Random forest perform better than Decison Tree on test data?

# %% [markdown]
# Random Forest performs better because it reduces overfitting. A single Decision Tree has high variance and can memorize the training data. Random Forest averages many trees built on random samples and features, which lowers variance and improves generalization.

# %% [markdown]
# Q19- Which regression technique among Linear Regresssion, Lasso Regression ,Ridge Regression, Decision Tree and Random Forest  provide best performance on test data?

# %% [markdown]
# Random Forest provides the best performance on the test data. It has the highest R² and the lowest RMSE and MAE compared to Linear Regression, Lasso, Ridge, and Decision Tree, indicating the best generalization performance.

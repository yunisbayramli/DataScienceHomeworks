# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Q1-Read the data https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv

# %%
#Q2- Get data information and number of rows and columns
import pandas as pd

# Read the dataset
url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df = pd.read_csv(url)

# Show data information
print("Data Information:")
df.info()

# Get number of rows and columns
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

# Alternatively (shows both at once)
print("Shape of dataset:", df.shape)
# Out:
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Income     400 non-null    float64
#  1   Limit      400 non-null    int64
#  2   Rating     400 non-null    int64
#  3   Cards      400 non-null    int64
#  4   Age        400 non-null    int64
#  5   Education  400 non-null    int64
#  6   Own        400 non-null    object
#  7   Student    400 non-null    object
#  8   Married    400 non-null    object
#  9   Region     400 non-null    object
#  10  Balance    400 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 34.5+ KB
# Number of rows: 400
# Number of columns: 11
# Shape of dataset: (400, 11)

# %%
#Q3-Get first 3 rows of data
import pandas as pd
url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
pd.read_csv(url)
print(df.head(3))
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Own Student Married Region  \
# 0   14.891   3606     283      2   34         11   No      No     Yes  South
# 1  106.025   6645     483      3   82         15  Yes     Yes     Yes   West
# 2  104.593   7075     514      4   71         11   No      No      No   West
#
#    Balance
# 0      333
# 1      903
# 2      580

# %%
#Q4-Get descriptive statistics of data
import pandas as pd

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
print(df.describe())
# Out:
#            Income         Limit      Rating       Cards         Age  \
# count  400.000000    400.000000  400.000000  400.000000  400.000000
# mean    45.218885   4735.600000  354.940000    2.957500   55.667500
# std     35.244273   2308.198848  154.724143    1.371275   17.249807
# min     10.354000    855.000000   93.000000    1.000000   23.000000
# 25%     21.007250   3088.000000  247.250000    2.000000   41.750000
# 50%     33.115500   4622.500000  344.000000    3.000000   56.000000
# 75%     57.470750   5872.750000  437.250000    4.000000   70.000000
# max    186.634000  13913.000000  982.000000    9.000000   98.000000
#
#         Education      Balance
# count  400.000000   400.000000
# mean    13.450000   520.015000
# std      3.125207   459.758877
# min      5.000000     0.000000
# 25%     11.000000    68.750000
# 50%     14.000000   459.500000
# 75%     16.000000   863.000000
# max     20.000000  1999.000000

# %%
#Q5-Use seasoborns heat map to generate following heatmap
# annot = True to print the correlation inside the square
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df=pd.read_csv(url)

numeric_df=df.select_dtypes(include=["int64", "float64"])

corr=numeric_df.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='magma')
plt.title("Correlation heatmap")
plt.show()

# %%
#Q6-Plot the density distribution of Balance
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df = pd.read_csv(url)

plt.figure(figsize=(8,6))
sns.kdeplot(df['Balance'], fill=False)
plt.title("Density Distribution of Balance")
plt.xlabel("Balance")
plt.ylabel("Density")
plt.show()

# %%
#Q7-Count the frequency values of each Region
import pandas as pd

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
pd.read_csv(url)

region_counts = df["Region"].value_counts()

print(region_counts)
# Out:
# Region
# South    199
# West     102
# East      99
# Name: count, dtype: int64

# %%
#Q8-List Percentage of  the Married people
import pandas as pd

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
pd.read_csv(url)

married_counts=(df["Married"].value_counts(normalize=True)*100)
print(married_counts)
# Out:
# Married
# Yes    61.25
# No     38.75
# Name: proportion, dtype: float64

# %%
#Q9-Create histogram of Balance
import pandas as pd
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df=pd.read_csv(url)

plt.figure(figsize=(8,6))
plt.hist(df["Balance"], bins=20)
plt.title("Histogram of Balance")
plt.xlabel("Balance")
plt.ylabel("Frequency")
plt.show()

# %%
#Q10-Get the frequency distribution of Region using bar graph
import pandas as pd
import matplotlib.pyplot as plt

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df = pd.read_csv(url)

regions_counts=(df["Region"].value_counts())

plt.figure(figsize=(8,6))
region_counts.plot(kind="bar")
plt.title("Frequency Distribution of Region")
plt.xlabel("Region")
plt.ylabel("Frequency")
plt.show()

# %%
#Q11-Get the mean income  of married people?
import pandas as pd

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df=pd.read_csv(url)

mean_mar_inc=df[df["Married"] == "Yes"]["Income"].mean()
print("Mean income of married people", mean_mar_inc)
# Out:
# Mean income of married people 46.21708163265307

# %%
#Q12-Get the scatter plot of Income and Limit
url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df=pd.read_csv(url)

plt.figure(figsize=(8,6))
plt.scatter(df["Income"], df["Limit"])
plt.title("Scatter Plot of Income and Limit")
plt.xlabel("Income")
plt.ylabel("Limmit")
# Out:
# Text(0, 0.5, 'Limmit')

# %%
#Q13-Create new column named IncomebyLimit by dividing Income to Limit.
import pandas as pd
url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"

df["IncomebyLimit"]=df["Income"] / df["Limit"]
print(df.head(5))

#Dr.Ogut, I just displayed first 5 rows in order to verify that it is true.
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Own Student Married Region  \
# 0   14.891   3606     283      2   34         11   No      No     Yes  South
# 1  106.025   6645     483      3   82         15  Yes     Yes     Yes   West
# 2  104.593   7075     514      4   71         11   No      No      No   West
# 3  148.924   9504     681      3   36         11  Yes      No      No   West
# 4   55.882   4897     357      2   68         16   No      No     Yes  South
#
#    Balance  IncomebyLimit
# 0      333       0.004130
# 1      903       0.015956
# 2      580       0.014783
# 3      964       0.015670
# 4      331       0.011411

# %%
# Q14-Create the pair plot using Seaborn library's pairplot
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df = pd.read_csv(url)

sns.pairplot(df)
plt.show()

# %%
#Q15- drop new column named IncomebyLimit from dataframe
import pandas as pd

url="https://raw.githubusercontent.com/ogut77/DataScience/main/data/Credit.csv"
df=pd.read_csv(url)

df.drop(columns=['IncomebyLimit'], inplace=True, errors='ignore')

print(df.head())
# Out:
#     Income  Limit  Rating  Cards  Age  Education  Own Student Married Region  \
# 0   14.891   3606     283      2   34         11   No      No     Yes  South
# 1  106.025   6645     483      3   82         15  Yes     Yes     Yes   West
# 2  104.593   7075     514      4   71         11   No      No      No   West
# 3  148.924   9504     681      3   36         11  Yes      No      No   West
# 4   55.882   4897     357      2   68         16   No      No     Yes  South
#
#    Balance
# 0      333
# 1      903
# 2      580
# 3      964
# 4      331
